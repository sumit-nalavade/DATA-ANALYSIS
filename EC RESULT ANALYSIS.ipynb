# %%
import pandas as pd
import numpy as np
dataset = pd.read_excel(r"/content/EC-11926_Sem-4.xlsx")

# %%
data = dataset.iloc[ 5: , [0,1,2,11,12,13,14,15,16] ]
data.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1                Unnamed: 2 Unnamed: 11 Unnamed: 12  \
# 5        NaN            NaN                       NaN    CA\n(20)   MSE\n(20)
# 6      11926  2263041242045       Pawar Nikita Sandip          15          17
# 7      11926  2263041926001     Ghagare Sushil Suresh          17          17
# 8      11926  2263041926002        Mulla Saniya Aslam          18          15
# 9      11926  2263041926003  Govardhan Madhav Gavhane          18          19
#
#   Unnamed: 13             Unnamed: 14         Unnamed: 15 Unnamed: 16
# 5   ESE\n(60)   Grace Marks Allocated  Total (With Grace)       Grade
# 6          41                       0                  73          BC
# 7          38                       0                  72          BC
# 8          41                       0                  74          BC
# 9          42                       0                  79          BB

# %%
data.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 11":"CA","Unnamed: 12":"MSE","Unnamed: 13":"ECE","Unnamed: 14":"Grace Marks Allocated","Unnamed: 15":"Total With Grace","Unnamed: 16":"Grade"}, inplace=True)
data.head(5)
data.reset_index(drop=True, inplace=True)
data = data.iloc[ 1: , : ]
data.head(5)
# Out:
#   Institute code            PRN              Students name  CA MSE ECE  \
# 1          11926  2263041242045        Pawar Nikita Sandip  15  17  41
# 2          11926  2263041926001      Ghagare Sushil Suresh  17  17  38
# 3          11926  2263041926002         Mulla Saniya Aslam  18  15  41
# 4          11926  2263041926003   Govardhan Madhav Gavhane  18  19  42
# 5          11926  2263041926004  Pailwan Parasharam Valmik  14  15  16
#
#   Grace Marks Allocated Total With Grace Grade
# 1                     0               73    BC
# 2                     0               72    BC
# 3                     0               74    BC
# 4                     0               79    BB
# 5                     4               49    EE

# %% [markdown]
# #***PS1***

# %%
PS1_data = data.iloc[ : , :10]
PS1_data.reset_index(drop=True, inplace=True)
# PS1_data.to_excel("PS1_data.xlsx")
PS1_data.head(5)
# Out:
#   Institute code            PRN              Students name  CA MSE ECE  \
# 0          11926  2263041242045        Pawar Nikita Sandip  15  17  41
# 1          11926  2263041926001      Ghagare Sushil Suresh  17  17  38
# 2          11926  2263041926002         Mulla Saniya Aslam  18  15  41
# 3          11926  2263041926003   Govardhan Madhav Gavhane  18  19  42
# 4          11926  2263041926004  Pailwan Parasharam Valmik  14  15  16
#
#   Grace Marks Allocated Total With Grace Grade
# 0                     0               73    BC
# 1                     0               72    BC
# 2                     0               74    BC
# 3                     0               79    BB
# 4                     4               49    EE

# %%
# PS1_data.to_excel("PS2_data.xlsx")

# %%
from matplotlib import pyplot as plt
import seaborn as sns
PS1_data.groupby('Grade').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.title('Grade Distribution - Power System 1')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
PS1_data.groupby("Grade").size()
# Out:
# Grade
# BB     4
# BC     6
# CC     3
# CD     5
# DD    12
# DE     8
# EE     7
# FF     6
# dtype: int64

# %%
PS1_AA=0
PS1_AB=0
PS1_BB=4
PS1_BC=6
PS1_CC=3
PS1_CD=5
PS1_DD=12
PS1_DE=8
PS1_EE=7
PS1_FF=6

# %% [markdown]
# #***EM2***

# %%
data2 = dataset.iloc[ 5: , [0,1,2,18,19,20,21,22,23] ]
data2.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1                Unnamed: 2 Unnamed: 18 Unnamed: 19  \
# 5        NaN            NaN                       NaN    CA\n(20)   MSE\n(20)
# 6      11926  2263041242045       Pawar Nikita Sandip          19          18
# 7      11926  2263041926001     Ghagare Sushil Suresh          17          18
# 8      11926  2263041926002        Mulla Saniya Aslam          19          20
# 9      11926  2263041926003  Govardhan Madhav Gavhane          18          19
#
#   Unnamed: 20             Unnamed: 21         Unnamed: 22 Unnamed: 23
# 5   ESE\n(60)   Grace Marks Allocated  Total (With Grace)       Grade
# 6          42                       0                  79          BB
# 7          45                       0                  80          BB
# 8          49                       0                  88          AA
# 9          51                       0                  88          AA

# %%
data2.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 18":"CA","Unnamed: 19":"MSE","Unnamed: 20":"ECE","Unnamed: 21":"Grace Marks Allocated","Unnamed: 22":"Total With Grace","Unnamed: 23":"Grade"}, inplace=True)
data2.reset_index(drop=True, inplace=True)
data2 = data2.iloc[ 1: , : ]
data2.head(5)
# Out:
#   Institute code            PRN              Students name  CA MSE ECE  \
# 1          11926  2263041242045        Pawar Nikita Sandip  19  18  42
# 2          11926  2263041926001      Ghagare Sushil Suresh  17  18  45
# 3          11926  2263041926002         Mulla Saniya Aslam  19  20  49
# 4          11926  2263041926003   Govardhan Madhav Gavhane  18  19  51
# 5          11926  2263041926004  Pailwan Parasharam Valmik  16  16  23
#
#   Grace Marks Allocated Total With Grace Grade
# 1                     0               79    BB
# 2                     0               80    BB
# 3                     0               88    AA
# 4                     0               88    AA
# 5                     0               55    DE

# %%
# data2.to_excel("EM2_data.xlsx")

# %%
data2.groupby('Grade').size()
# Out:
# Grade
# AA    5
# AB    5
# BB    7
# BC    7
# CC    3
# CD    8
# DD    7
# DE    3
# EE    1
# FF    5
# dtype: int64

# %%
EM_AA=5
EM_AB=5
EM_BB=7
EM_BC=7
EM_CC=3
EM_CD=8
EM_DD=7
EM_DE=3
EM_EE=1
EM_FF=5

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data2.groupby('Grade').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.title('Grade Distribution - Electrical Machines 2')
# Out:
# Text(0.5, 1.0, 'Grade Distribution - Electrical Machines 2')

# %% [markdown]
# #***CA***

# %%
data3 = dataset.iloc[ 5: , [0,1,2,25,26,27,28,29,30] ]
data3.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1                Unnamed: 2 Unnamed: 25 Unnamed: 26  \
# 5        NaN            NaN                       NaN    CA\n(20)   MSE\n(20)
# 6      11926  2263041242045       Pawar Nikita Sandip          20          15
# 7      11926  2263041926001     Ghagare Sushil Suresh          20          15
# 8      11926  2263041926002        Mulla Saniya Aslam          20          18
# 9      11926  2263041926003  Govardhan Madhav Gavhane          20          17
#
#   Unnamed: 27             Unnamed: 28         Unnamed: 29 Unnamed: 30
# 5   ESE\n(60)   Grace Marks Allocated  Total (With Grace)       Grade
# 6          49                       0                  84          AB
# 7          22                       0                  57          DD
# 8          30                       0                  68          CC
# 9          26                       0                  63          CD

# %%
data3.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 25":"CA","Unnamed: 26":"MSE","Unnamed: 27":"ESE","Unnamed: 28":"Grace Marks Allocated","Unnamed: 29":"Total With Grace","Unnamed: 30":"Grade"}, inplace=True)
data3.reset_index(drop=True, inplace=True)
data3 = data3.iloc[ 1: , : ]
data3.head(5)
# Out:
#   Institute code            PRN              Students name  CA MSE ESE  \
# 1          11926  2263041242045        Pawar Nikita Sandip  20  15  49
# 2          11926  2263041926001      Ghagare Sushil Suresh  20  15  22
# 3          11926  2263041926002         Mulla Saniya Aslam  20  18  30
# 4          11926  2263041926003   Govardhan Madhav Gavhane  20  17  26
# 5          11926  2263041926004  Pailwan Parasharam Valmik  19  17  20
#
#   Grace Marks Allocated Total With Grace Grade
# 1                     0               84    AB
# 2                     0               57    DD
# 3                     0               68    CC
# 4                     0               63    CD
# 5                     0               56    DD

# %%
# data3.to_excel("CA_data.xlsx")

# %%
data3.groupby('Grade').size()
# Out:
# Grade
# AB     1
# CC     2
# CD     4
# DD    10
# DE     9
# EE    13
# FF    12
# dtype: int64

# %%
ca_AA=0
ca_AB=1
ca_BB=0
ca_BC=0
ca_CC=2
ca_CD=4
ca_DD=10
ca_DE=9
ca_EE=13
ca_FF=12

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data3.groupby('Grade').size().plot(kind='bar', color=sns.palettes.mpl_palette('Dark2'))
plt.title('Grade Distribution - Computer Algorithm')
# Out:
# Text(0.5, 1.0, 'Grade Distribution - Computer Algorithm')

# %% [markdown]
# ##***CAOS***

# %%
data4 = dataset.iloc[ 5: , [0,1,2,32,33,34,35,36,37] ]
data4.head(5)
# Out:
#   Unnamed: 0     Unnamed: 1                Unnamed: 2 Unnamed: 32 Unnamed: 33  \
# 5        NaN            NaN                       NaN    CA\n(20)   MSE\n(20)
# 6      11926  2263041242045       Pawar Nikita Sandip          18          19
# 7      11926  2263041926001     Ghagare Sushil Suresh          17          13
# 8      11926  2263041926002        Mulla Saniya Aslam          17          18
# 9      11926  2263041926003  Govardhan Madhav Gavhane          18          18
#
#   Unnamed: 34             Unnamed: 35         Unnamed: 36 Unnamed: 37
# 5   ESE\n(60)   Grace Marks Allocated  Total (With Grace)       Grade
# 6          41                       0                  78          BB
# 7          20                       0                  50          EE
# 8          37                       0                  72          BC
# 9          39                       0                  75          BC

# %%
data4.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 32":"CA","Unnamed: 33":"MSE","Unnamed: 34":"ESE","Unnamed: 35":"Grace Marks Allocated","Unnamed: 36":"Total With Grace","Unnamed: 37":"Grade"}, inplace=True)
data4.reset_index(drop=True, inplace=True)
data4 = data3.iloc[ 1: , : ]
# data4.to_excel("CAOS_data.xlsx")
data4.head(5)
# Out:
#   Institute code            PRN                   Students name  CA MSE ESE  \
# 2          11926  2263041926001           Ghagare Sushil Suresh  20  15  22
# 3          11926  2263041926002              Mulla Saniya Aslam  20  18  30
# 4          11926  2263041926003        Govardhan Madhav Gavhane  20  17  26
# 5          11926  2263041926004       Pailwan Parasharam Valmik  19  17  20
# 6          11926  2263041926005  Yellurkar Dhanshree Shashikant  19  12  21
#
#   Grace Marks Allocated Total With Grace Grade
# 2                     0               57    DD
# 3                     0               68    CC
# 4                     0               63    CD
# 5                     0               56    DD
# 6                     0               52    DE

# %%
data4.groupby('Grade').size()
# Out:
# Grade
# CC     2
# CD     4
# DD    10
# DE     9
# EE    13
# FF    12
# dtype: int64

# %%
caos_AA = 0
caos_AB = 0
caos_BB = 0
caos_BC = 0
caos_CC	=2
caos_CD=	4
caos_DD	=10
caos_DE=	9
caos_EE	=13
caos_FF	=12

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data4.groupby('Grade').size().plot(kind="bar", color=sns.palettes.mpl_palette('Dark2'))
plt.title('Grade Distribution - Computer Algorithm and Operating System')
plt.xlabel("Grade")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #***NT***

# %%
data5 = dataset.iloc[5: , : ]
data5.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 3":"Subject","Unnamed: 4":"CA","Unnamed: 5":"MSE","Unnamed: 6":"ESE","Unnamed: 7":"Grace Marks Allocated","Unnamed: 8":"Total (With Grace)","Unnamed: 9":"Grade"}, inplace=True)
nt_data = data5.iloc[ : , :10]
nt_data.reset_index(drop=True, inplace=True)
nt_data.head(5)
nt_data = nt_data.drop(0)
nt_data.drop(columns=nt_data["Subject"].name, inplace=True)
# nt_data.to_excel("NT_data.xlsx")
nt_data.head(5)
# Out:
# <ipython-input-26-854427a4d5ad>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data5.rename(columns={'Unnamed: 0': 'Institute code',"Unnamed: 1":"PRN","Unnamed: 2":"Students name","Unnamed: 3":"Subject","Unnamed: 4":"CA","Unnamed: 5":"MSE","Unnamed: 6":"ESE","Unnamed: 7":"Grace Marks Allocated","Unnamed: 8":"Total (With Grace)","Unnamed: 9":"Grade"}, inplace=True)
#   Institute code            PRN              Students name  CA MSE ESE  \
# 1          11926  2263041242045        Pawar Nikita Sandip  15  16  33
# 2          11926  2263041926001      Ghagare Sushil Suresh  16  20  31
# 3          11926  2263041926002         Mulla Saniya Aslam  17  19  35
# 4          11926  2263041926003   Govardhan Madhav Gavhane  16  20  35
# ...

# %%
nt_data.groupby('Grade').size()
# Out:
# Grade
# BC     6
# CC     7
# CD     8
# DD    12
# DE     8
# EE     4
# FF     6
# dtype: int64

# %%
nt_AA=0
nt_AB=0
nt_BB=0
nt_BC=6
nt_CC=7
nt_CD=8
nt_DD=12
nt_DE=8
nt_EE=4
nt_FF=6

# %%
from matplotlib import pyplot as plt
import seaborn as sns
nt_data.groupby('Grade').size().plot(kind="bar", color=sns.palettes.mpl_palette('Dark2'))
plt.title("Grade Distribution - Network Theory")
plt.xlabel("Grade")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #**DISTINCTION**

# %%
distinction_per_subject = {"NT":nt_AA+nt_AB+nt_BB,"CAOS":caos_AA+caos_AB+caos_BB,"PS1":PS1_AA+PS1_AB+PS1_BB,"CA":ca_AA+ca_AB+ca_BB,"EM2":EM_AA+EM_AB+EM_BB}
distinction= pd.DataFrame(distinction_per_subject,index=[0])
distinction
# Out:
#    NT  CAOS  PS1  CA  EM2
# 0   0     0    4   1   17

# %%
plt.bar(distinction.columns,distinction.iloc[0], color=sns.palettes.mpl_palette('Dark2'))
plt.title("Students with 75+ Marks (Pass with Distinction)")
plt.show()

# %% [markdown]
# #**FIRST_CLASS**

# %%
firstclass_per_subject = {"NT":nt_BC+nt_CC+nt_CD+nt_DD,"CAOS":caos_BC+caos_CC+caos_CD+caos_DD,"PS1":PS1_BC+PS1_CC+PS1_CD+PS1_DD,"CA":ca_BC+ca_CC+ca_CD+ca_DD,"EM2":EM_CC+EM_CD+EM_DD}
firstclass = pd.DataFrame(firstclass_per_subject,index=[0])
plt.bar(firstclass.columns, firstclass.iloc[0], color=sns.palettes.mpl_palette('Dark2'))
plt.title("Students with 56 to 75 marks (Pass with FirstClass)")
plt.yticks(np.arange(0, 36, 3))
plt.show()

# %% [markdown]
# #**SECONS_CLASS**

# %%
import numpy as np
second_class = {"NT":nt_DD+nt_DE,"CAOS":caos_DD+caos_DE,"PS1":PS1_DD+PS1_DE,"CA":ca_DD+ca_DE,"EM2":EM_DD+EM_DE}
second_class =pd.DataFrame(second_class,index=[0])
plt.bar(second_class.columns,second_class.iloc[0],color=sns.palettes.mpl_palette('Dark2'))
plt.title("Students with 51 to 60 Marks (Pass with SecondClass)")
plt.yticks(np.arange(0, 22, 2))
plt.show()

# %% [markdown]
# #***PASS_CLASS***

# %%
pass_class = {"NT":nt_EE,"CAOS":caos_EE,"PS1":PS1_EE,"CA":ca_EE,"EM2":EM_EE}
passclass = pd.DataFrame(pass_class,index=[0])
plt.bar(passclass.columns,passclass.iloc[0],color=sns.palettes.mpl_palette('Dark2'))
plt.yticks(np.arange(0, 16, 2))
plt.title("Students with 41 to 50 Marks (Pass with PassClass)")
# Out:
# Text(0.5, 1.0, 'Students with 41 to 50 Marks (Pass with PassClass)')

# %% [markdown]
# #FAIL-CLASS

# %%
fail_class = {"NT":nt_FF,"CAOS":caos_FF,"PS1":PS1_FF,"CA":ca_FF,"EM2":EM_FF}
fail = pd.DataFrame(fail_class,index=[0])
plt.bar(fail.columns,fail.iloc[0],color=sns.palettes.mpl_palette('Dark2'))
plt.title("Students with 0 to 40 Marks (Fail)")
# Out:
# Text(0.5, 1.0, 'Students with 0 to 40 Marks (Fail)')

# %%
percent_result={"NT ": (45/51)*100,
"CAOS": (39/51)*100,
"PS1":(45/51)*100,
"CA":(39/51)*100,
"EM2":(46/51)*100}
percent_result = pd.DataFrame(percent_result,index=[0])
percent_result = pd.DataFrame(percent_result)
percent_result
# Out:
#          NT        CAOS        PS1         CA        EM2
# 0  88.235294  76.470588  88.235294  76.470588  90.196078

# %%
plt.bar(percent_result.columns,percent_result.iloc[0],color=sns.palettes.mpl_palette('Dark2'))
plt.title("Each subject's result in %")
plt.yticks(np.arange(0, 101,10))
plt.show()
